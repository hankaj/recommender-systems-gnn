# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# base
df_lgcn_base = pd.read_csv('../../results/gnn/metrics_2023-11-20 20 40 43.csv', skiprows=2)
df_lgcn_base
# Out:
#     Epoch      Loss  Precision    Recall      Hits
# 0       0  0.693071   0.276906  0.181643  0.943355
# 1       1  0.692128   0.285512  0.187565  0.943355
# 2       2  0.689468   0.273529  0.174951  0.938998
# 3       3  0.685077   0.265904  0.167328  0.936819
# 4       4  0.678735   0.262527  0.164751  0.932462
# ..    ...       ...        ...       ...       ...
# 95     95  0.337340   0.317538  0.214894  0.947712
# 96     96  0.337435   0.317102  0.213832  0.945534
# 97     97  0.338092   0.318410  0.214444  0.945534
# 98     98  0.335604   0.319717  0.215255  0.945534
# 99     99  0.336518   0.319390  0.215377  0.943355
#
# [100 rows x 5 columns]

# %%
df_lgcn_xavier = pd.read_csv('../../results/gnn/metrics_2023-11-20 20 51 21.csv', skiprows=2)
df_lgcn_less_layers = pd.read_csv('../../results/gnn/metrics_2023-11-20 21 01 44.csv', skiprows=2)
df_lgcn_more_layers = pd.read_csv('../../results/gnn/metrics_2023-11-26 10 22 22.csv', skiprows=2)
df_lgcn_less_neurons = pd.read_csv('../../results/gnn/metrics_2023-11-20 21 39 04.csv', skiprows=2)
df_lgcn_more_neurons = pd.read_csv('../../results/gnn/metrics_2023-11-20 21 47 55.csv', skiprows=2)

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
# fig.set_figheight(10)
fig.set_figwidth(19)
fig.suptitle('Normal init vs Xavier init')

ax1.plot(df_lgcn_base["Epoch"], df_lgcn_base["Loss"], label='Normal init training loss')
ax1.plot(df_lgcn_xavier["Epoch"], df_lgcn_xavier["Loss"], label='Xavier init training loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

ax2.plot(df_lgcn_base["Epoch"], df_lgcn_base["Precision"], label='Normal init test precision')
ax2.plot(df_lgcn_xavier["Epoch"], df_lgcn_xavier["Precision"], label='Xavier init test precision')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Precision')
ax2.legend()

ax3.plot(df_lgcn_base["Epoch"], df_lgcn_base["Recall"], label='Normal init test recall')
ax3.plot(df_lgcn_xavier["Epoch"], df_lgcn_xavier["Recall"], label='Xavier init test recall')
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Recall')
ax3.legend()

ax4.plot(df_lgcn_base["Epoch"], df_lgcn_base["Hits"], label='Normal init test hits ratio')
ax4.plot(df_lgcn_xavier["Epoch"], df_lgcn_xavier["Hits"], label='Xavier init test hits ratio')
ax4.set_xlabel('Epoch')
ax4.set_ylabel('Hits ratio')
ax4.legend()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
fig.set_figwidth(19)
fig.suptitle('Impact of number of layers')

ax1.plot(df_lgcn_base["Epoch"], df_lgcn_base["Loss"], label='Base number of layers training loss')
ax1.plot(df_lgcn_more_layers["Epoch"], df_lgcn_more_layers["Loss"], label='More layers training loss')
ax1.plot(df_lgcn_less_layers["Epoch"], df_lgcn_less_layers["Loss"], label='Less layers training loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

ax2.plot(df_lgcn_base["Epoch"], df_lgcn_base["Precision"], label='Base number of layers test precision')
ax2.plot(df_lgcn_more_layers["Epoch"], df_lgcn_more_layers["Precision"], label='More layers test precision')
ax2.plot(df_lgcn_less_layers["Epoch"], df_lgcn_less_layers["Precision"], label='Less layers test precision')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Precision')
ax2.legend()

ax3.plot(df_lgcn_base["Epoch"], df_lgcn_base["Recall"], label='Base number of layers test recall')
ax3.plot(df_lgcn_more_layers["Epoch"], df_lgcn_more_layers["Recall"], label='More layers test recall')
ax3.plot(df_lgcn_less_layers["Epoch"], df_lgcn_less_layers["Recall"], label='Less layers test recall')
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Recall')
ax3.legend()

ax4.plot(df_lgcn_base["Epoch"], df_lgcn_base["Hits"], label='More layers test hits ratio')
ax4.plot(df_lgcn_more_layers["Epoch"], df_lgcn_more_layers["Hits"], label='More layers test hits ratio')
ax4.plot(df_lgcn_less_layers["Epoch"], df_lgcn_less_layers["Hits"], label='Less layers test hits ratio')
ax4.set_xlabel('Epoch')
ax4.set_ylabel('Hits ratio')
ax4.legend()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
fig.set_figwidth(22)
fig.suptitle('Impact of number of neurons')

ax1.plot(df_lgcn_base["Epoch"], df_lgcn_base["Loss"], label='Base number of neurons training loss')
ax1.plot(df_lgcn_more_neurons["Epoch"], df_lgcn_more_neurons["Loss"], label='More neurons training loss')
ax1.plot(df_lgcn_less_neurons["Epoch"], df_lgcn_less_neurons["Loss"], label='Less neurons training loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

ax2.plot(df_lgcn_base["Epoch"], df_lgcn_base["Precision"], label='Base number of neurons test precision')
ax2.plot(df_lgcn_more_neurons["Epoch"], df_lgcn_more_neurons["Precision"], label='More neurons test precision')
ax2.plot(df_lgcn_less_neurons["Epoch"], df_lgcn_less_neurons["Precision"], label='Less neurons test precision')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Precision')
ax2.legend()

ax3.plot(df_lgcn_base["Epoch"], df_lgcn_base["Recall"], label='Base number of neurons test recall')
ax3.plot(df_lgcn_more_neurons["Epoch"], df_lgcn_more_neurons["Recall"], label='More neurons test recall')
ax3.plot(df_lgcn_less_neurons["Epoch"], df_lgcn_less_neurons["Recall"], label='Less neurons test recall')
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Recall')
ax3.legend()

ax4.plot(df_lgcn_base["Epoch"], df_lgcn_base["Hits"], label='Base number of neurons test hits ratio')
ax4.plot(df_lgcn_more_neurons["Epoch"], df_lgcn_more_neurons["Hits"], label='More neurons test hits ratio')
ax4.plot(df_lgcn_less_neurons["Epoch"], df_lgcn_less_neurons["Hits"], label='Less neurons test hits ratio')
ax4.set_xlabel('Epoch')
ax4.set_ylabel('Hits ratio')
ax4.legend()

# %%
# base
df_ngcf_base = pd.read_csv('../../results/gnn/metrics_2023-11-21 10 50 15.csv', skiprows=2)
df_ngcf_base
# Out:
#     Epoch      Loss  Precision    Recall      Hits
# 0       0  0.688205   0.208932  0.147818  0.919390
# 1       1  0.637032   0.225381  0.153880  0.915033
# 2       2  0.517331   0.227451  0.157190  0.930283
# 3       3  0.450912   0.235839  0.144638  0.928105
# 4       4  0.438972   0.248693  0.149762  0.921569
# ..    ...       ...        ...       ...       ...
# 95     95  0.301997   0.298148  0.176267  0.919390
# 96     96  0.302455   0.308061  0.196364  0.932462
# 97     97  0.296770   0.307516  0.197093  0.941176
# 98     98  0.303355   0.308932  0.195730  0.954248
# 99     99  0.300030   0.307952  0.200502  0.947712
#
# [100 rows x 5 columns]

# %%
df_ngcf_normal = pd.read_csv('../../results/gnn/metrics_2023-11-21 10 59 47.csv', skiprows=2)
df_ngcf_less_layers = pd.read_csv('../../results/gnn/metrics_2023-11-21 11 51 57.csv', skiprows=2)
df_ngcf_more_layers = pd.read_csv('../../results/gnn/metrics_2023-11-21 11 41 04.csv', skiprows=2)
df_ngcf_less_neurons = pd.read_csv('../../results/gnn/metrics_2023-11-21 12 00 25.csv', skiprows=2)
df_ngcf_more_neurons = pd.read_csv('../../results/gnn/metrics_2023-11-21 12 36 05.csv', skiprows=2)
df_ngcf_features = pd.read_csv('../../results/gnn/metrics_2023-11-21 12 54 16.csv', skiprows=2)

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
# fig.set_figheight(10)
fig.set_figwidth(19)
fig.suptitle('Xavier init vs Normal init')

ax1.plot(df_ngcf_base["Epoch"], df_ngcf_base["Loss"], label='Xavier init training loss')
ax1.plot(df_ngcf_normal["Epoch"], df_ngcf_normal["Loss"], label='Normal init training loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

ax2.plot(df_ngcf_base["Epoch"], df_ngcf_base["Precision"], label='Xavier init test precision')
ax2.plot(df_ngcf_normal["Epoch"], df_ngcf_normal["Precision"], label='Normal init test precision')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Precision')
ax2.legend()

ax3.plot(df_ngcf_base["Epoch"], df_ngcf_base["Recall"], label='Xavier init test recall')
ax3.plot(df_ngcf_normal["Epoch"], df_ngcf_normal["Recall"], label='Normal init test recall')
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Recall')
ax3.legend()

ax4.plot(df_ngcf_base["Epoch"], df_ngcf_base["Hits"], label='Xavier init test hits ratio')
ax4.plot(df_ngcf_normal["Epoch"], df_ngcf_normal["Hits"], label='Normal init test hits ratio')
ax4.set_xlabel('Epoch')
ax4.set_ylabel('Hits ratio')
ax4.legend()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
fig.set_figwidth(19)
fig.suptitle('Impact of number of layers')

ax1.plot(df_ngcf_base["Epoch"], df_ngcf_base["Loss"], label='Base number of layers training loss')
ax1.plot(df_ngcf_more_layers["Epoch"], df_ngcf_more_layers["Loss"], label='More layers training loss')
ax1.plot(df_ngcf_less_layers["Epoch"], df_ngcf_less_layers["Loss"], label='Less layers training loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

ax2.plot(df_ngcf_base["Epoch"], df_ngcf_base["Precision"], label='Base number of layers test precision')
ax2.plot(df_ngcf_more_layers["Epoch"], df_ngcf_more_layers["Precision"], label='More layers test precision')
ax2.plot(df_ngcf_less_layers["Epoch"], df_ngcf_less_layers["Precision"], label='Less layers test precision')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Precision')
ax2.legend()

ax3.plot(df_ngcf_base["Epoch"], df_ngcf_base["Recall"], label='Base number of layers test recall')
ax3.plot(df_ngcf_more_layers["Epoch"], df_ngcf_more_layers["Recall"], label='More layers test recall')
ax3.plot(df_ngcf_less_layers["Epoch"], df_ngcf_less_layers["Recall"], label='Less layers test recall')
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Recall')
ax3.legend()

ax4.plot(df_ngcf_base["Epoch"], df_ngcf_base["Hits"], label='Base number of layers test hits ratio')
ax4.plot(df_ngcf_more_layers["Epoch"], df_ngcf_more_layers["Hits"], label='More layers test hits ratio')
ax4.plot(df_ngcf_less_layers["Epoch"], df_ngcf_less_layers["Hits"], label='Less layers test hits ratio')
ax4.set_xlabel('Epoch')
ax4.set_ylabel('Hits ratio')
ax4.legend()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
fig.set_figwidth(19)
fig.suptitle('Impact of number of neurons')

ax1.plot(df_ngcf_base["Epoch"], df_ngcf_base["Loss"], label='Base number of neurons training loss')
ax1.plot(df_ngcf_more_neurons["Epoch"], df_ngcf_more_neurons["Loss"], label='More number of neurons training loss')
ax1.plot(df_ngcf_less_neurons["Epoch"], df_ngcf_less_neurons["Loss"], label='Less number of neurons training loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

ax2.plot(df_ngcf_base["Epoch"], df_ngcf_base["Precision"], label='Base number of neurons test precision')
ax2.plot(df_ngcf_more_neurons["Epoch"], df_ngcf_more_neurons["Precision"], label='More neurons test precision')
ax2.plot(df_ngcf_less_neurons["Epoch"], df_ngcf_less_neurons["Precision"], label='Less neurons test precision')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Precision')
ax2.legend()

ax3.plot(df_ngcf_base["Epoch"], df_ngcf_base["Recall"], label='Base number of neurons test recall')
ax3.plot(df_ngcf_more_neurons["Epoch"], df_ngcf_more_neurons["Recall"], label='More neurons test recall')
ax3.plot(df_ngcf_less_neurons["Epoch"], df_ngcf_less_neurons["Recall"], label='Less neurons test recall')
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Recall')
ax3.legend()

ax4.plot(df_ngcf_base["Epoch"], df_ngcf_base["Hits"], label='Base number of neurons test hits ratio')
ax4.plot(df_ngcf_more_neurons["Epoch"], df_ngcf_more_neurons["Hits"], label='More neurons test hits ratio')
ax4.plot(df_ngcf_less_neurons["Epoch"], df_ngcf_less_neurons["Hits"], label='Less neurons test hits ratio')
ax4.set_xlabel('Epoch')
ax4.set_ylabel('Hits ratio')
ax4.legend()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
fig.set_figwidth(19)
fig.suptitle('Impact of using item and user features')

ax1.plot(df_ngcf_base["Epoch"], df_ngcf_base["Loss"], label='Without features training loss')
ax1.plot(df_ngcf_features["Epoch"], df_ngcf_features["Loss"], label='With features training loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

ax2.plot(df_ngcf_base["Epoch"], df_ngcf_base["Precision"], label='Without features test precision')
ax2.plot(df_ngcf_features["Epoch"], df_ngcf_features["Precision"], label='With features test precision')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Precision')
ax2.legend()

ax3.plot(df_ngcf_base["Epoch"], df_ngcf_base["Recall"], label='Without features test recall')
ax3.plot(df_ngcf_features["Epoch"], df_ngcf_features["Recall"], label='With features test recall')
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Recall')
ax3.legend()

ax4.plot(df_ngcf_base["Epoch"], df_ngcf_base["Hits"], label='Without features test hits ratio')
ax4.plot(df_ngcf_features["Epoch"], df_ngcf_features["Hits"], label='With features test hits ratio')
ax4.set_xlabel('Epoch')
ax4.set_ylabel('Hits ratio')
ax4.legend()

# %%
df_lgcn_final = pd.read_csv('../../results/gnn/metrics_2023-12-16 17 34 08.csv', skiprows=2)
df_ngcf_final = pd.read_csv('../../results/gnn/metrics_2023-12-16 17 22 56.csv', skiprows=2)

# %%
df_ngcf_final
# Out:
#      Epoch      Loss  Precision    Recall      Hits
# 0        0  0.640517   0.231917  0.153672  0.923747
# 1        1  0.463810   0.243355  0.149305  0.923747
# 2        2  0.443568   0.250545  0.146562  0.910675
# 3        3  0.434129   0.248475  0.148385  0.912854
# 4        4  0.424667   0.239978  0.142476  0.906318
# ..     ...       ...        ...       ...       ...
# 995    995  0.192168   0.343682  0.244576  0.973856
# 996    996  0.193433   0.338235  0.238661  0.978214
# 997    997  0.193662   0.338017  0.237156  0.971678
# 998    998  0.191507   0.332898  0.235381  0.973856
# 999    999  0.190935   0.330392  0.234147  0.971678
#
# [1000 rows x 5 columns]

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
fig.set_figwidth(21)
fig.suptitle('Comparison of LightGCN and NGCF')

ax1.plot(df_lgcn_final["Epoch"], df_lgcn_final["Loss"], label='LightGCN training loss')
ax1.plot(df_ngcf_final["Epoch"], df_ngcf_final["Loss"], label='NGCF training loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

ax2.plot(df_lgcn_final["Epoch"], df_lgcn_final["Precision"], label='LightGCN test precision')
ax2.plot(df_ngcf_final["Epoch"], df_ngcf_final["Precision"], label='NGCF test precision')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Precision')
ax2.legend()

ax3.plot(df_lgcn_final["Epoch"], df_lgcn_final["Recall"], label='LightGCN test recall')
ax3.plot(df_ngcf_final["Epoch"], df_ngcf_final["Recall"], label='NGCF test recall')
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Recall')
ax3.legend()

ax4.plot(df_lgcn_final["Epoch"], df_lgcn_final["Hits"], label='LightGCN test hits ratio')
ax4.plot(df_ngcf_final["Epoch"], df_ngcf_final["Hits"], label='NGCF test hits ratio')
ax4.set_xlabel('Epoch')
ax4.set_ylabel('Hits ratio')
ax4.legend()

# %%
df_lgcn_final['Precision'][999], df_lgcn_final['Recall'][999], df_lgcn_final['Hits'][999]
# Out:
# (0.4004357697397535, 0.2816045092081972, 0.9803921568627452)
